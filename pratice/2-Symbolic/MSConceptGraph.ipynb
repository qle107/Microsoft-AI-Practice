# %%
import urllib
import json
import ssl

# %%
def http(x):
    ssl._create_default_https_context = ssl._create_unverified_context
    response = urllib.request.urlopen(x)
    data = response.read()
    return data.decode('utf-8')

def query(x):
    return json.loads(http("https://concept.research.microsoft.com/api/Concept/ScoreByProb?instance={}&topK=10".format(urllib.parse.quote(x))))

query('microsoft')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-cb35664fa659> in <cell line: 0>()
#      12     return json.loads(http("https://concept.research.microsoft.com/api/Concept/ScoreByProb?instance={}&topK=10".format(urllib.parse.quote(x))))
#      13
# ---> 14 query('microsoft')
#
# <ipython-input-3-cb35664fa659> in query(x)
#      10
#      11 def query(x):
# ---> 12     return json.loads(http("https://concept.research.microsoft.com/api/Concept/ScoreByProb?instance={}&topK=10".format(urllib.parse.quote(x))))
#      13
#      14 query('microsoft')
#
# <ipython-input-3-cb35664fa659> in http(x)
#       5 def http(x):
#       6     ssl._create_default_https_context = ssl._create_unverified_context
# ----> 7     response = urllib.request.urlopen(x)
#       8     data = response.read()
#       9     return data.decode('utf-8')
#
# ...

# %%
newsapi_key = '262de668b1354103b3ab3ce33b5ca9ca'
def get_news(country='us'):
    res = json.loads(http("https://newsapi.org/v2/top-headlines?country={0}&apiKey={1}".format(country,newsapi_key)))
    return res['articles']

all_titles = [x['title'] for x in get_news('us')+get_news('gb')]

# %%
all_titles
# Out:
# ['Israeli strike destroys part of last fully functioning hospital in Gaza City as offensive escalates - CNN',
#  '‘A Minecraft Movie’ Blasts To $551M Global; ‘The Amateur’ Spies $32M – International Box Office - Deadline',
#  'Pennsylvania police say an arson at the governor’s residence forced Gov. Shapiro and his family to evacuate - CNN',
#  'Former top health official criticizes RFK Jr. for downplaying measles deaths - CBS News',
#  'Former LSU receiver Lacy found dead at age 24 - ESPN',
#  'Trump in excellent cognitive and physical health, says White House doctor - BBC',
#  'Alexander Volkanovski down for Yair Rodriguez or Mosvar Evloev after UFC 314 title win - MMA Junkie',
#  "National Guard to help Albuquerque fight crime, but some wonder if it's necessary - NBC News",
#  'Kylie Jenner and Timothée Chalamet Were Spotted Packing on the PDA at Coachella - instyle.com',
#  "The biggest trial in Meta's history starts today. Here's what to know - NPR",
# ...

# %% [markdown]
# Extract nouns from news titles. Use TextBlob library to do this, which simplifies a lot of typical NLP tasks like this.

# %%
import sys
# !{sys.executable} -m pip install textblob
# !{sys.executable} -m textblob.download_corpora
from textblob import TextBlob
# Out:
# ...
# [nltk_data] Downloading package brown to /root/nltk_data...
# [nltk_data]   Unzipping corpora/brown.zip.
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger_eng.zip.
# [nltk_data] Downloading package conll2000 to /root/nltk_data...
# [nltk_data]   Unzipping corpora/conll2000.zip.
# [nltk_data] Downloading package movie_reviews to /root/nltk_data...
# [nltk_data]   Unzipping corpora/movie_reviews.zip.
# Finished.

# %%
w = {}
for x in all_titles:
    for n in TextBlob(x).noun_phrases:
        if n in w:
            w[n].append(x)
        else:
            w[n]=[x]

# %%
{ x:len(w[x]) for x in w.keys()}
# Out:
# {'israeli': 1,
#  'strike destroys part': 1,
#  'gaza': 1,
#  'offensive escalates': 1,
#  'cnn': 2,
#  'minecraft movie': 1,
#  'blasts': 1,
#  '$ 551m': 1,
#  'global': 1,
#  'amateur ’': 1,
#  'spies': 1,
#  '$ 32m –': 1,
#  'international box office': 1,
#  'deadline': 1,
#  'pennsylvania': 1,
#  'governor ’ s residence': 1,
#  'gov': 1,
#  'shapiro': 1,
#  'top health': 1,
#  'official criticizes': 1,
#  'rfk jr.': 1,
#  'measles deaths': 1,
#  'cbs news': 1,
#  'lsu receiver': 1,
#  'lacy': 1,
#  'espn': 1,
#  'trump': 3,
#  'excellent cognitive': 1,
#  'physical health': 1,
#  'white house doctor': 1,
#  'bbc': 1,
#  'alexander volkanovski': 1,
#  'yair rodriguez': 1,
#  'mosvar evloev': 1,
#  'ufc': 1,
#  'mma junkie': 1,
#  'national guard': 1,
#  'albuquerque': 1,
#  'fight crime': 1,
#  'nbc news': 1,
#  'kylie jenner': 1,
#  'timothée chalamet were spotted packing': 1,
#  'pda': 1,
#  'coachella': 1,
#  'meta': 1,
#  "'s history": 1,
#  'npr': 2,
#  'mistakenly': 1,
# ...

# %% [markdown]
# From word by word -> General term. Calling REST each time

# %%
w = {}
for x in all_titles:
    for noun in TextBlob(x).noun_phrases:
        terms = query(noun.replace(' ','%20'))
        for term in [u for u in terms.keys() if terms[u]>0.1]:
            if term in w:
                w[term].append(x)
            else:
                w[term]=[x]
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# /usr/lib/python3.11/urllib/request.py in do_open(self, http_class, req, **http_conn_args)
#    1347             try:
# -> 1348                 h.request(req.get_method(), req.selector, req.data, headers,
#    1349                           encode_chunked=req.has_header('Transfer-encoding'))
#
# /usr/lib/python3.11/http/client.py in request(self, method, url, body, headers, encode_chunked)
#    1302         """Send a complete request to the server."""
# -> 1303         self._send_request(method, url, body, headers, encode_chunked)
#    1304
#
# /usr/lib/python3.11/http/client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1348             body = _encode(body, 'body')
# -> 1349         self.endheaders(body, encode_chunked=encode_chunked)
#    1350
#
# ...

# %% [markdown]
# Failed because API is not responsing, web down

# %%
{ x:len(w[x]) for x in w.keys() if len(w[x])>3}

# %%
print('\nECONOMY:\n'+'\n'.join(w['economy']))
print('\nNATION:\n'+'\n'.join(w['nation']))
print('\nPERSON:\n'+'\n'.join(w['person']))
